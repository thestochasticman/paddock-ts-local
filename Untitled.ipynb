# %%
import os

# %%
from PaddockTSLocal.Legend import *
from PaddockTSLocal.Query import get_example_query
import pickle

# %%
stub = get_example_query().get_stub()

# %%
ds2i = pickle.load(open(f"{DS2I_DIR}/{stub}.pkl", 'rb'))

# %%
ds2i['nbart_red'].isel(time=0).rio.to_raster(f'{DS2_DIR}/chris_test.tif')

# %%
ds2i.rio.crs
# Out:
# CRS.from_wkt('PROJCS["WGS 84 / NSIDC EASE-Grid 2.0 Global",GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4326"]],PROJECTION["Cylindrical_Equal_Area"],PARAMETER["standard_parallel_1",30],PARAMETER["central_meridian",0],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1],AXIS["Easting",EAST],AXIS["Northing",NORTH],AUTHORITY["EPSG","6933"]]')

# %%
ds2i_2 = pickle.load(open(f"{DS2I_DIR}/ARBO_taia_ds2i.pkl", 'rb'))

# %%
ds2i_2.rio.transform
# Out:
# <bound method XRasterBase.transform of <rioxarray.raster_dataset.RasterDataset object at 0x3005d1210>>

# %%
ds2i.rio.crs
# Out:
# CRS.from_wkt('PROJCS["WGS 84 / NSIDC EASE-Grid 2.0 Global",GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4326"]],PROJECTION["Cylindrical_Equal_Area"],PARAMETER["standard_parallel_1",30],PARAMETER["central_meridian",0],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1],AXIS["Easting",EAST],AXIS["Northing",NORTH],AUTHORITY["EPSG","6933"]]')

# %%
output_path = f"{OUT_DIR}/{stub}_manpad_RGB.mp4"
xr_animation(ds2_2i, 
            bands = ['nbart_red', 'nbart_green', 'nbart_blue'], 
            output_path = output_path, 
            # show_gdf = pol, 
            gdf_kwargs={"edgecolor": 'white'})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 output_path = f"{OUT_DIR}/{stub}_manpad_RGB.mp4"
# ----> 2 xr_animation(ds2_2i,
#       3             bands = ['nbart_red', 'nbart_green', 'nbart_blue'],
#       4             output_path = output_path,
#       5             # show_gdf = pol,
#       6             gdf_kwargs={"edgecolor": 'white'})
#
# NameError: name 'xr_animation' is not defined

# %%
ds2i
# Out:
# <xarray.Dataset> Size: 98MB
# Dimensions:           (y: 215, x: 194, time: 31)
# Coordinates:
#   * y                 (y) float64 2kB -4.039e+06 -4.039e+06 ... -4.041e+06
#   * x                 (x) float64 2kB 1.432e+07 1.432e+07 ... 1.432e+07
#     spatial_ref       int32 4B 6933
#   * time              (time) datetime64[ns] 248B 2020-01-03T00:15:53.433114 ....
# Data variables: (12/16)
#     nbart_blue        (time, y, x) float32 5MB 873.0 876.0 876.0 ... nan nan nan
#     nbart_green       (time, y, x) float32 5MB 1.227e+03 1.246e+03 ... nan nan
#     nbart_red         (time, y, x) float32 5MB 1.874e+03 1.915e+03 ... nan nan
#     nbart_red_edge_1  (time, y, x) float32 5MB 2.163e+03 2.163e+03 ... nan nan
#     nbart_red_edge_2  (time, y, x) float32 5MB 2.342e+03 2.342e+03 ... nan nan
#     nbart_red_edge_3  (time, y, x) float32 5MB 2.487e+03 2.487e+03 ... nan nan
#     ...                ...
#     bg                (time, y, x) float64 10MB 0.3551 0.3792 0.3792 ... nan nan
# ...

# %%
ds2i['nbart_red'].isel(time=0)
# Out:
# <xarray.DataArray 'nbart_red' (y: 215, x: 194)> Size: 167kB
# array([[1874., 1915., 1915., ..., 1910., 2004., 2056.],
#        [1939., 1984., 1984., ..., 1995., 2045., 2074.],
#        [2035., 2035., 2068., ..., 2019., 2035., 2087.],
#        ...,
#        [1885., 1942., 1844., ...,  987.,  959.,  893.],
#        [1959., 1876., 1802., ...,  967.,  924.,  887.],
#        [1962., 1858., 1804., ...,  977.,  978.,  924.]], dtype=float32)
# Coordinates:
#   * y            (y) float64 2kB -4.039e+06 -4.039e+06 ... -4.041e+06 -4.041e+06
#   * x            (x) float64 2kB 1.432e+07 1.432e+07 ... 1.432e+07 1.432e+07
#     spatial_ref  int32 4B 6933
#     time         datetime64[ns] 8B 2020-01-03T00:15:53.433114
